# %% [markdown]
# ### AQS Data Exploration

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
aqs_df = pd.read_csv('../data/epa_aqs_data.csv', index_col=0)

# %% [markdown]
# #### Filter the Resulting DataFrame (Only Keep Parameters with Data For All Four States)

# %%
aqs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2191 entries, 0 to 2190
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state_code                   2191 non-null   int64
#  1   county_code                  2191 non-null   int64
#  2   site_number                  2191 non-null   int64
#  3   parameter_code               2191 non-null   int64
#  4   poc                          2191 non-null   int64
#  5   latitude                     2191 non-null   float64
#  6   longitude                    2191 non-null   float64
#  7   datum                        2191 non-null   object
#  8   parameter                    2191 non-null   object
#  9   sample_duration_code         2191 non-null   object
#  10  sample_duration              2191 non-null   object
#  11  pollutant_standard           1638 non-null   object
#  12  metric_used                  2191 non-null   object
#  13  method                       1517 non-null   object
#  14  year                         2191 non-null   int64
#  15  units_of_measure             2191 non-null   object
#  16  event_type                   2191 non-null   object
#  17  observation_count            2191 non-null   int64
#  18  observation_percent          2191 non-null   float64
#  19  validity_indicator           2191 non-null   object
#  20  valid_day_count              2191 non-null   int64
#  21  required_day_count           2191 non-null   int64
#  22  exceptional_data_count       2191 non-null   int64
#  23  null_observation_count       2191 non-null   int64
#  24  primary_exceedance_count     1128 non-null   float64
#  25  secondary_exceedance_count   993 non-null    float64
#  26  certification_indicator      2191 non-null   object
#  27  arithmetic_mean              2191 non-null   float64
#  28  standard_deviation           2191 non-null   float64
#  29  first_max_value              2191 non-null   float64
#  30  first_max_datetime           2191 non-null   object
#  31  second_max_value             2189 non-null   float64
#  32  second_max_datetime          2189 non-null   object
#  33  third_max_value              2189 non-null   float64
#  34  third_max_datetime           2189 non-null   object
#  35  fourth_max_value             2189 non-null   float64
#  36  fourth_max_datetime          2189 non-null   object
#  37  first_max_nonoverlap_value   70 non-null     float64
#  38  first_max_n_o_datetime       70 non-null     object
#  39  second_max_nonoverlap_value  70 non-null     float64
#  40  second_max_n_o_datetime      70 non-null     object
#  41  ninety_ninth_percentile      2191 non-null   float64
#  42  ninety_eighth_percentile     2191 non-null   float64
#  43  ninety_fifth_percentile      2191 non-null   float64
#  44  ninetieth_percentile         2191 non-null   float64
#  45  seventy_fifth_percentile     2191 non-null   float64
#  46  fiftieth_percentile          2190 non-null   float64
#  47  tenth_percentile             2171 non-null   float64
#  48  local_site_name              2189 non-null   object
#  49  site_address                 2191 non-null   object
#  50  state                        2191 non-null   object
#  51  county                       2191 non-null   object
#  52  city                         2056 non-null   object
#  53  cbsa_code                    2191 non-null   int64
#  54  cbsa                         2191 non-null   object
#  55  date_of_last_change          2191 non-null   object
# dtypes: float64(20), int64(12), object(24)
# memory usage: 975.7+ KB

# %%
aqs_df.head()
# Out:
#    state_code  county_code  site_number  parameter_code  poc  latitude  \
# 0           6           37         6012           42101    1  34.38344
# 1           6           37         6012           42101    1  34.38344
# 2           6           37          113           42101    1  34.05111
# 3           6           37          113           42101    1  34.05111
# 4           6           37         1701           42101    1  34.06703
#
#    longitude  datum        parameter sample_duration_code  ...  \
# 0 -118.52840  WGS84  Carbon monoxide                    1  ...
# 1 -118.52840  WGS84  Carbon monoxide                    Z  ...
# 2 -118.45636  WGS84  Carbon monoxide                    1  ...
# 3 -118.45636  WGS84  Carbon monoxide                    Z  ...
# 4 -117.75140  WGS84  Carbon monoxide                    1  ...
#
#   fiftieth_percentile tenth_percentile   local_site_name  \
# 0                 0.2              0.1     Santa Clarita
# 1                 0.2              0.1     Santa Clarita
# 2                 0.3              0.2  West Los Angeles
# 3                 0.3              0.2  West Los Angeles
# 4                 0.3              0.0            Pomona
#
#                                site_address       state       county  \
# 0  22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 1  22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 2             VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 3             VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 4                 924 N. GAREY AVE., POMONA  California  Los Angeles
#
#                city  cbsa_code                                cbsa  \
# 0     Santa Clarita      31080  Los Angeles-Long Beach-Anaheim, CA
# 1     Santa Clarita      31080  Los Angeles-Long Beach-Anaheim, CA
# 2  West Los Angeles      31080  Los Angeles-Long Beach-Anaheim, CA
# 3  West Los Angeles      31080  Los Angeles-Long Beach-Anaheim, CA
# 4            Pomona      31080  Los Angeles-Long Beach-Anaheim, CA
#
#   date_of_last_change
# 0          2021-11-08
# 1          2021-11-08
# 2          2021-11-18
# 3          2021-11-18
# 4          2021-11-08
#
# [5 rows x 56 columns]

# %% [markdown]
# #### Rename Relevant Fields

# %%
aqs_df = aqs_df.rename(columns={'first_max_value':'max_value_1', 
                                'first_max_datetime':'max_month_1', 
                                'second_max_value':'max_value_2', 
                                'second_max_datetime':'max_month_2',
                                'third_max_value':'max_value_3', 
                                'third_max_datetime':'max_month_3', 
                                'fourth_max_value':'max_value_4', 
                                'fourth_max_datetime':'max_month_4',
                                'ninety_ninth_percentile':'perc_99',
                                'ninety_fifth_percentile':'perc_95',
                                'ninetieth_percentile':'perc_90',
                                'seventy_fifth_percentile':'perc_75'})

# %% [markdown]
# #### Create a Calculated Field for the Average of the Four Max Measurement Values

# %%
aqs_df['avg_max_value'] = [round(np.mean([row.max_value_1, row.max_value_2, row.max_value_3, row.max_value_4]), 1) for ind, row in aqs_df.iterrows()]

# %%
aqs_df
# Out:
#       state_code  county_code  site_number  parameter_code  poc   latitude  \
# 0              6           37         6012           42101    1  34.383440
# 1              6           37         6012           42101    1  34.383440
# 2              6           37          113           42101    1  34.051110
# 3              6           37          113           42101    1  34.051110
# 4              6           37         1701           42101    1  34.067030
# ...          ...          ...          ...             ...  ...        ...
# 2186          47           37           23           88502    3  36.176382
# 2187          47           37           23           88502    3  36.176382
# 2188          47           37           23           88502    5  36.176382
# 2189          47           37           23           88502    3  36.176382
# 2190          47           37           23           88502    3  36.176382
#
#       longitude  datum                               parameter  \
# 0    -118.52840  WGS84                         Carbon monoxide
# 1    -118.52840  WGS84                         Carbon monoxide
# 2    -118.45636  WGS84                         Carbon monoxide
# 3    -118.45636  WGS84                         Carbon monoxide
# 4    -117.75140  WGS84                         Carbon monoxide
# ...         ...    ...                                     ...
# 2186  -86.73890  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 2187  -86.73890  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 2188  -86.73890  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 2189  -86.73890  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 2190  -86.73890  WGS84  Acceptable PM2.5 AQI & Speciation Mass
#
#      sample_duration_code  ... tenth_percentile   local_site_name  \
# 0                       1  ...              0.1     Santa Clarita
# 1                       Z  ...              0.1     Santa Clarita
# 2                       1  ...              0.2  West Los Angeles
# 3                       Z  ...              0.2  West Los Angeles
# 4                       1  ...              0.0            Pomona
# ...                   ...  ...              ...               ...
# 2186                    X  ...              5.9         Lockeland
# 2187                    1  ...              4.6         Lockeland
# 2188                    7  ...              5.3         Lockeland
# 2189                    X  ...              6.3         Lockeland
# 2190                    1  ...              4.4         Lockeland
#
#                                   site_address       state       county  \
# 0     22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 1     22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 2                VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 3                VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 4                    924 N. GAREY AVE., POMONA  California  Los Angeles
# ...                                        ...         ...          ...
# 2186      105 SOUTH 17TH ST @ LOCKELAND SCHOOL   Tennessee     Davidson
# 2187      105 SOUTH 17TH ST @ LOCKELAND SCHOOL   Tennessee     Davidson
# 2188      105 SOUTH 17TH ST @ LOCKELAND SCHOOL   Tennessee     Davidson
# 2189      105 SOUTH 17TH ST @ LOCKELAND SCHOOL   Tennessee     Davidson
# 2190      105 SOUTH 17TH ST @ LOCKELAND SCHOOL   Tennessee     Davidson
#
#                   city cbsa_code  \
# 0        Santa Clarita     31080
# 1        Santa Clarita     31080
# 2     West Los Angeles     31080
# 3     West Los Angeles     31080
# 4               Pomona     31080
# ...                ...       ...
# 2186         Nashville     34980
# 2187         Nashville     34980
# 2188         Nashville     34980
# 2189         Nashville     34980
# 2190         Nashville     34980
#
#                                                 cbsa  date_of_last_change  \
# 0                 Los Angeles-Long Beach-Anaheim, CA           2021-11-08
# 1                 Los Angeles-Long Beach-Anaheim, CA           2021-11-08
# 2                 Los Angeles-Long Beach-Anaheim, CA           2021-11-18
# 3                 Los Angeles-Long Beach-Anaheim, CA           2021-11-18
# 4                 Los Angeles-Long Beach-Anaheim, CA           2021-11-08
# ...                                              ...                  ...
# 2186  Nashville-Davidson--Murfreesboro--Franklin, TN           2020-12-21
# 2187  Nashville-Davidson--Murfreesboro--Franklin, TN           2020-12-21
# 2188  Nashville-Davidson--Murfreesboro--Franklin, TN           2020-05-21
# 2189  Nashville-Davidson--Murfreesboro--Franklin, TN           2020-12-21
# 2190  Nashville-Davidson--Murfreesboro--Franklin, TN           2020-12-21
#
#      avg_max_value
# 0              1.2
# 1              0.8
# 2              2.8
# 3              1.4
# 4              2.0
# ...            ...
# 2186          25.5
# 2187          37.2
# 2188          23.7
# 2189          18.6
# 2190          83.7
#
# [2191 rows x 57 columns]

# %% [markdown]
# ##### Classify Measurement Percentile???

# %% [markdown]
# #### Relabel Params

# %%
aqs_df.parameter.value_counts()
# Out:
# PM2.5 - Local Conditions                  718
# Ozone                                     380
# Nitrogen dioxide (NO2)                    202
# Nitric oxide (NO)                         155
# Acceptable PM2.5 AQI & Speciation Mass    155
# Sulfur dioxide                            149
# Carbon monoxide                           140
# PM10 Total 0-10um STP                     123
# Name: parameter, dtype: int64

# %%
for ind, row in aqs_df.iterrows():
    if row.parameter == 'PM2.5 - Local Conditions':
        aqs_df.loc[ind, 'parameter'] = 'PM2.5 - LC'
    elif row.parameter == 'Acceptable PM2.5 AQI & Speciation Mass':
        aqs_df.loc[ind, 'parameter'] = 'PM2.5 - Acc/SM'
aqs_df['parameter'] = ['PM2.5 - LC' if row.parameter == 'PM2.5 - Local Conditions' else row.county for index, row in aqs_df.iterrows()]

# %% [markdown]
# #### Relabel Atlanta's Counties as a Joint County

# %%
aqs_df['county'] = ['Fulton, DeKalb' if row.state == 'Georgia' else row.county for index, row in aqs_df.iterrows()]

# %% [markdown]
# #### Subset for Parameters with Data in All Four States

# %%
state_counts = pd.DataFrame(aqs_df.groupby(['parameter_code','state']).state.count())
state_counts = state_counts.rename(columns={'state':'count'}).reset_index()

# %%
aqs_params = state_counts.groupby('parameter_code').state.count()
valid_params = list(aqs_params[aqs_params.values == 4].index)
aqs_df = aqs_df.loc[aqs_df.parameter_code.isin(valid_params)]

# %% [markdown]
# #### Extract the Month from the Date Fields

# %%
aqs_df['max_month_1']
# Out:
# 0       2011-02-07 08:00
# 1       2011-12-21 23:00
# 2       2011-10-04 05:00
# 3       2011-12-31 23:00
# 4       2011-12-31 20:00
#               ...
# 2186    2011-05-31 00:00
# 2187    2011-08-01 06:00
# 2188    2011-06-08 00:00
# 2189    2016-07-22 00:00
# 2190    2016-11-13 21:00
# Name: max_month_1, Length: 2022, dtype: object

# %%
pd.to_datetime(aqs_df['max_month_1']).dt.month
# Out:
# 0        2
# 1       12
# 2       10
# 3       12
# 4       12
#         ..
# 2186     5
# 2187     8
# 2188     6
# 2189     7
# 2190    11
# Name: max_month_1, Length: 2022, dtype: int64

# %%
pd.set_option('mode.chained_assignment', None)
cols = ['max_month_1', 'max_month_2', 'max_month_3', 'max_month_4']
for col in cols:
    aqs_df[col] = pd.to_datetime(aqs_df[col]).dt.month
aqs_df.head()
# Out:
#    state_code  county_code  site_number  parameter_code  poc  latitude  \
# 0           6           37         6012           42101    1  34.38344
# 1           6           37         6012           42101    1  34.38344
# 2           6           37          113           42101    1  34.05111
# 3           6           37          113           42101    1  34.05111
# 4           6           37         1701           42101    1  34.06703
#
#    longitude  datum        parameter sample_duration_code  ...  \
# 0 -118.52840  WGS84  Carbon monoxide                    1  ...
# 1 -118.52840  WGS84  Carbon monoxide                    Z  ...
# 2 -118.45636  WGS84  Carbon monoxide                    1  ...
# 3 -118.45636  WGS84  Carbon monoxide                    Z  ...
# 4 -117.75140  WGS84  Carbon monoxide                    1  ...
#
#   tenth_percentile   local_site_name  \
# 0              0.1     Santa Clarita
# 1              0.1     Santa Clarita
# 2              0.2  West Los Angeles
# 3              0.2  West Los Angeles
# 4              0.0            Pomona
#
#                                site_address       state       county  \
# 0  22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 1  22224 PLACERITA CANYON RD, SANTA CLARITA  California  Los Angeles
# 2             VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 3             VA HOSPITAL, WEST LOS ANGELES  California  Los Angeles
# 4                 924 N. GAREY AVE., POMONA  California  Los Angeles
#
#                city cbsa_code                                cbsa  \
# 0     Santa Clarita     31080  Los Angeles-Long Beach-Anaheim, CA
# 1     Santa Clarita     31080  Los Angeles-Long Beach-Anaheim, CA
# 2  West Los Angeles     31080  Los Angeles-Long Beach-Anaheim, CA
# 3  West Los Angeles     31080  Los Angeles-Long Beach-Anaheim, CA
# 4            Pomona     31080  Los Angeles-Long Beach-Anaheim, CA
#
#    date_of_last_change avg_max_value
# 0           2021-11-08           1.2
# 1           2021-11-08           0.8
# 2           2021-11-18           2.8
# 3           2021-11-18           1.4
# 4           2021-11-08           2.0
#
# [5 rows x 57 columns]

# %% [markdown]
# #### Subset for Relevant Fields

# %%
aqs_df = aqs_df[['parameter', 'year', 'state', 'county', 'metric_used', 'method', 
                 'event_type', 'observation_count', 'observation_percent', 'validity_indicator', 'valid_day_count', 'required_day_count', 
                 'poc', 'exceptional_data_count', 'primary_exceedance_count', 'certification_indicator',
                 'arithmetic_mean', 'standard_deviation', 'units_of_measure', 'avg_max_value',
                 'max_month_1', 'max_value_1', 'max_month_2', 'max_value_2', 
                 'max_month_3', 'max_value_3', 'max_month_4', 'max_value_4', 
                 'perc_99', 'perc_95', 'perc_90', 'perc_75', 
                 'state_code', 'county_code', 'parameter_code', 'duration''latitude', 'longitude']]

# %%
aqs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2022 entries, 0 to 2190
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      2022 non-null   int64
#  1   state                     2022 non-null   object
#  2   county                    2022 non-null   object
#  3   parameter                 2022 non-null   object
#  4   metric_used               2022 non-null   object
#  5   method                    1348 non-null   object
#  6   event_type                2022 non-null   object
#  7   observation_count         2022 non-null   int64
#  8   observation_percent       2022 non-null   float64
#  9   validity_indicator        2022 non-null   object
#  10  valid_day_count           2022 non-null   int64
#  11  required_day_count        2022 non-null   int64
#  12  poc                       2022 non-null   int64
#  13  exceptional_data_count    2022 non-null   int64
#  14  primary_exceedance_count  1128 non-null   float64
#  15  certification_indicator   2022 non-null   object
#  16  arithmetic_mean           2022 non-null   float64
#  17  standard_deviation        2022 non-null   float64
#  18  units_of_measure          2022 non-null   object
#  19  avg_max_value             2022 non-null   float64
#  20  max_value_1               2022 non-null   float64
#  21  max_month_1               2022 non-null   int64
#  22  max_value_2               2022 non-null   float64
#  23  max_month_2               2022 non-null   int64
#  24  max_value_3               2022 non-null   float64
#  25  max_month_3               2022 non-null   int64
#  26  max_value_4               2022 non-null   float64
#  27  max_month_4               2022 non-null   int64
#  28  perc_99                   2022 non-null   float64
#  29  perc_95                   2022 non-null   float64
#  30  perc_90                   2022 non-null   float64
#  31  perc_75                   2022 non-null   float64
#  32  state_code                2022 non-null   int64
#  33  county_code               2022 non-null   int64
#  34  parameter_code            2022 non-null   int64
#  35  latitude                  2022 non-null   float64
#  36  longitude                 2022 non-null   float64
# dtypes: float64(15), int64(13), object(9)
# memory usage: 600.3+ KB

# %%
aqs_df.metric_used.value_counts()
# Out:
# Daily Mean                                                              439
# Observed Values                                                         418
# Quarterly Means of Daily Means                                          341
# Daily maximum of 8 hour running average of observed hourly values       190
# Observed values                                                         101
# Daily Maximum 1-hour average                                            101
# Daily maxima of observed hourly values (between 9:00 AM and 8:00 PM)     95
# Daily maximum of 8-hour running average                                  95
# Obseved hourly values                                                    70
# 8-Hour running average (end hour) of observed hourly values              70
# Daily maximum 1-hour average                                             34
# Daily Average of observed values                                         34
# 3-Hour block average of observed hourly values                           34
# Name: metric_used, dtype: int64

# %%
aqs_df.groupby(['parameter_code', 'units_of_measure']).parameter.count()
# Out:
# parameter_code  units_of_measure
# 42101           Parts per million                140
# 42401           Parts per billion                149
# 42601           Parts per billion                155
# 42602           Parts per billion                202
# 44201           Parts per million                380
# 81102           Micrograms/cubic meter (25 C)    123
# 88101           Micrograms/cubic meter (LC)      718
# 88502           Micrograms/cubic meter (LC)      155
# Name: parameter, dtype: int64

# %%
# NOTE: 300 Records are 'NOT VALID'
aqs_df.validity_indicator.value_counts()
# Out:
# Y    1707
# N     315
# Name: validity_indicator, dtype: int64

# %%
param_avgs = aqs_df.groupby(['parameter', 'year', 'state', 'county', 'units_of_measure']).avg_max_value.mean()
# Out:
# parameter                               year  state       county          units_of_measure
# Acceptable PM2.5 AQI & Speciation Mass  2011  California  Los Angeles     Micrograms/cubic meter (LC)     68.407407
#                                                           San Diego       Micrograms/cubic meter (LC)     79.020000
#                                               Colorado    Denver          Micrograms/cubic meter (LC)     16.700000
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     43.133333
#                                               Tennessee   Davidson        Micrograms/cubic meter (LC)     28.800000
#                                         2016  California  Los Angeles     Micrograms/cubic meter (LC)     65.666667
#                                                           San Diego       Micrograms/cubic meter (LC)     50.057143
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     57.150000
#                                               Tennessee   Davidson        Micrograms/cubic meter (LC)     51.150000
#                                         2021  California  Los Angeles     Micrograms/cubic meter (LC)    102.497436
#                                                           San Diego       Micrograms/cubic meter (LC)     44.770000
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     46.277778
# Carbon monoxide                         2011  California  Los Angeles     Parts per million                2.328125
#                                                           San Diego       Parts per million                2.266667
#                                               Colorado    Denver          Parts per million                2.216667
#                                               Georgia     Fulton, DeKalb  Parts per million                1.550000
#                                               Tennessee   Davidson        Parts per million                1.800000
#                                         2016  California  Los Angeles     Parts per million                1.750000
#                                                           San Diego       Parts per million                1.437500
#                                               Colorado    Denver          Parts per million                2.383333
# Name: avg_max_value, dtype: float64

# %%
param_avgs.head(20)
# Out:
# parameter                               year  state       county          units_of_measure
# Acceptable PM2.5 AQI & Speciation Mass  2011  California  Los Angeles     Micrograms/cubic meter (LC)     68.407407
#                                                           San Diego       Micrograms/cubic meter (LC)     79.020000
#                                               Colorado    Denver          Micrograms/cubic meter (LC)     16.700000
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     43.133333
#                                               Tennessee   Davidson        Micrograms/cubic meter (LC)     28.800000
#                                         2016  California  Los Angeles     Micrograms/cubic meter (LC)     65.666667
#                                                           San Diego       Micrograms/cubic meter (LC)     50.057143
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     57.150000
#                                               Tennessee   Davidson        Micrograms/cubic meter (LC)     51.150000
#                                         2021  California  Los Angeles     Micrograms/cubic meter (LC)    102.497436
#                                                           San Diego       Micrograms/cubic meter (LC)     44.770000
#                                               Georgia     Fulton, DeKalb  Micrograms/cubic meter (LC)     46.277778
# Carbon monoxide                         2011  California  Los Angeles     Parts per million                2.328125
#                                                           San Diego       Parts per million                2.266667
#                                               Colorado    Denver          Parts per million                2.216667
#                                               Georgia     Fulton, DeKalb  Parts per million                1.550000
#                                               Tennessee   Davidson        Parts per million                1.800000
#                                         2016  California  Los Angeles     Parts per million                1.750000
#                                                           San Diego       Parts per million                1.437500
#                                               Colorado    Denver          Parts per million                2.383333
# Name: avg_max_value, dtype: float64

# %%
aqs_df.to_csv('../data/aqs_data_cleaned.csv')

# %% [markdown]
# #### Merge the AQI Category Data with the Filtered Parameter Data

# %% [markdown]
# #You can use the module pandasql to join two dataframed based on value between two values
#
# print df_1
#
#   timestamp              A          B
# 0 2016-05-14 10:54:33    0.020228   0.026572
# 1 2016-05-14 10:54:34    0.057780   0.175499
# 2 2016-05-14 10:54:35    0.098808   0.620986
# 3 2016-05-14 10:54:36    0.158789   1.014819
# 4 2016-05-14 10:54:39    0.038129   2.384590
#
#
# print df_2
#
#   start                end                  event
# 0 2016-05-14 10:54:31  2016-05-14 10:54:33  E1
# 1 2016-05-14 10:54:34  2016-05-14 10:54:37  E2
# 2 2016-05-14 10:54:38  2016-05-14 10:54:42  E3
#
# import pandasql as ps
#
# sqlcode = '''
# select df_1.timestamp
# ,df_1.A
# ,df_1.B
# ,df_2.event
# from df_1
# inner join df_2
# on df_1.timestamp ?[where df_1.timestamp]? between df_2.start and df_2.end
# '''
#
# newdf = ps.sqldf(sqlcode,locals())
#
# SELECT *
# FROM A,B
# WHERE A_value between B_low and B_high
