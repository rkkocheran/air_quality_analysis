# %% [markdown]
# Data INTRO Source of Air Pollution and its effect on Respiratory Health:<br>
# https://www.epa.gov/pmcourse/particle-pollution-and-respiratory-effects

# %% [markdown]
# - Limit the size of queries. Our database contains billions of values and you may request more than you intend. If you are unsure of the amount of data, start small and work your way up. We request that you limit queries to 1,000,000 rows of data each. **You can use the "observation count" field on the annualData service to determine how much data exists for a time-parameter-geography combination.** If you have any questions or need advice, please contact us.
# - Limit the frequency of queries. Our system can process a limited load. If scripting requests, please wait for one request to complete before submitting another and do not make more than 10 requests per minute. Also, we request a pause of 5 seconds between requests and adjust accordingly for response time and size.

# %%
import requests
import json
import pandas as pd
import re
import time

# %%
with open('../data/credentials.json') as file:
    credentials = json.load(file)
epa_key = credentials['epa_key']
epa_email = credentials['epa_email']

# %% [markdown]
# #### Static Variables

# %%
# US FIPS codes - state level
fips_ca = '06'
fips_co = '08'
fips_ga = '13'
fips_tn = '47'

# US FIPS codes - county level
fips_sd = '073'
fips_la = '037'
fips_den = '031'
fips_ful = '121'
fips_dek = '089'
fips_dav = '037'

# %% [markdown]
# #### Obtain the AQS (Air Quality System) Parameter Codes
# AQI = Air Quality Index<br>
# - The AQI is a nationally uniform color-coded index for reporting and forecasting daily air quality. It is used to report on the most common ambient air pollutants that are regulated under the Clean Air Act: **ground-level _ozone_, particle pollution (_PM10 and PM2.5_), _carbon monoxide (CO)_, _nitrogen dioxide (NO2)_, and _sulfur dioxide (SO2)_.** The AQI tells the public how clean or polluted the air is and how to avoid health effects associated with poor air quality.
# - The AQI focuses on health effects that may be experienced within a few hours or days after breathing polluted air and uses a normalized scale from 0 to 500; the higher the AQI value, the greater the level of pollution and the greater the health concern. An AQI value of 100 generally corresponds to the level of the short-term National Ambient Air Quality Standard for the pollutant. **AQI values at and below 100 are generally considered to be satisfactory. When AQI values are above 100, air quality is considered to be unhealthy, at first for members of populations at greatest risk of a health effect, then for the entire population as AQI values get higher (greater than 150).**

# %% [markdown]
# #### Filter the Parameter Codes

# %%
param_codes = pd.read_csv('../data/parameter_codes.csv')
param_codes = param_codes.rename(columns={'Parameter Code': 'code', 
                                                 'Parameter': 'param',
                                                 'Parameter Abbreviation': 'abbr',
                                                 'Still Valid': 'valid',
                                                 'Standard Units':'std_units'})
param_codes = param_codes[['code', 'param', 'abbr', 'valid', 'std_units']].sort_values(by='code').reset_index(drop=True)
param_codes['code'] = param_codes.code.astype('string')

# %%
param_codes = param_codes.loc[param_codes['valid'] == 'YES']
param_codes = param_codes.loc[param_codes.param.str.contains('^PM10|^PM2.5 [STP|Raw|Total]|Ozone', regex=True, na=False, case=False) |
                              param_codes.abbr.str.contains('^[CSN]{1}O2{0,1}$|Smoke', regex=True, na=False, )]
print(len(param_codes))
param_codes
# Out:
# 13
#        code                        param   abbr valid  \
# 534   42101              Carbon monoxide     CO   YES
# 535   42102               Carbon dioxide    CO2   YES
# 549   42401               Sulfur dioxide    SO2   YES
# 555   42601            Nitric oxide (NO)     NO   YES
# 556   42602       Nitrogen dioxide (NO2)    NO2   YES
# 855   44201                        Ozone     O3   YES
# 1029  81102        PM10 Total 0-10um STP   PM10   YES
# 1030  81103                 PM10-2.5 STP    PMC   YES
# 1031  81104                    PM2.5 STP  PM2.5   YES
# 1173  85101                    PM10 - LC   LC10   YES
# 1243  86101  PM10-2.5 - Local Conditions  LCPMC   YES
# 1447  88500      PM2.5 Total Atmospheric    NaN   YES
# 1448  88501               PM2.5 Raw Data    NaN   YES
#
#                           std_units
# 534               Parts per million
# 535               Parts per million
# 549               Parts per billion
# 555               Parts per billion
# 556               Parts per billion
# 855               Parts per million
# 1029  Micrograms/cubic meter (25 C)
# 1030  Micrograms/cubic meter (25 C)
# 1031  Micrograms/cubic meter (25 C)
# 1173    Micrograms/cubic meter (LC)
# 1243    Micrograms/cubic meter (LC)
# 1447    Micrograms/cubic meter (LC)
# 1448    Micrograms/cubic meter (LC)

# %% [markdown]
# #### Obtain the Air Quality Data (Limit of 5 Codes per Request)

# %%
resp = pd.DataFrame()
endpoint = 'https://aqs.epa.gov/data/api/annualData/byCounty?'

# Loop through the parameter codes, 5 at a time
param_list_full = [c for c in param_codes.code]

#while len(param_list_full):
i=0
while i < 1:
    if len(param_list_full) >= 5:
        param_list_limit = param_list_full[:5]
        param_list_full = param_list_full[5:]
    else:
        param_list_limit = param_list_full
        param_list_full = param_list_full[len(param_list_full):]

    # PERFORM THE REQUEST 
    request_params = ','.join(param_list_limit)
    params = {'email': epa_email,
              'key': epa_key,
              'param': request_params,
              'bdate': '20200101',
              'edate': '20200101',
              'state': fips_ca,
              'county': fips_sd}
    
    # WAIT AT LEAST 5 SECONDS BETWEEN REQUESTS
    time.sleep(8)
    resp = requests.get(endpoint, params=params).json()
    i+=1

# %%
resp['Header']
# Out:
# [{'status': 'Success',
#   'request_time': '2022-12-09T16:38:21-05:00',
#   'url': 'https://aqs.epa.gov/data/api/annualData/byCounty?email=rbzing%40gmail.com&key=mauvecat88&param=42101%2C42102%2C42401%2C42601%2C42602&bdate=20200101&edate=20200101&state=06&county=073',
#   'rows': 35}]

# %%
pd.DataFrame(resp['Data'])
# Out:
#    state_code county_code site_number parameter_code  poc   latitude  \
# 0          06         073        1006          42601    1  32.842318
# 1          06         073        0001          42601    1  32.631242
# 2          06         073        1022          42601    3  32.789565
# 3          06         073        1014          42601    1  32.578160
# 4          06         073        1026          42601    1  32.710177
# 5          06         073        1017          42601    1  32.985442
# 6          06         073        1016          42601    1  32.845709
# 7          06         073        1008          42601    1  33.217055
# 8          06         073        1006          42602    1  32.842318
# 9          06         073        0001          42602    1  32.631242
# 10         06         073        1022          42602    2  32.789565
# 11         06         073        1022          42602    1  32.789565
# 12         06         073        1014          42602    1  32.578160
# 13         06         073        1026          42602    1  32.710177
# 14         06         073        1017          42602    1  32.985442
# 15         06         073        1016          42602    1  32.845709
# 16         06         073        1008          42602    1  33.217055
# 17         06         073        1022          42401    1  32.789565
# 18         06         073        1022          42101    1  32.789565
# 19         06         073        1017          42101    1  32.985442
# 20         06         073        1006          42602    1  32.842318
# 21         06         073        0001          42602    1  32.631242
# 22         06         073        1022          42602    2  32.789565
# 23         06         073        1022          42602    1  32.789565
# 24         06         073        1014          42602    1  32.578160
# 25         06         073        1026          42602    1  32.710177
# 26         06         073        1017          42602    1  32.985442
# 27         06         073        1016          42602    1  32.845709
# 28         06         073        1008          42602    1  33.217055
# 29         06         073        1022          42401    1  32.789565
# 30         06         073        1022          42401    1  32.789565
# 31         06         073        1022          42401    1  32.789565
# 32         06         073        1022          42401    2  32.789565
# 33         06         073        1022          42101    1  32.789565
# 34         06         073        1017          42101    1  32.985442
#
#      longitude  datum               parameter sample_duration_code  ...  \
# 0  -116.768293  NAD83       Nitric oxide (NO)                    1  ...
# 1  -117.059088  NAD83       Nitric oxide (NO)                    1  ...
# 2  -116.944308  NAD83       Nitric oxide (NO)                    1  ...
# 3  -116.921350  NAD83       Nitric oxide (NO)                    1  ...
# 4  -117.142665  NAD83       Nitric oxide (NO)                    1  ...
# 5  -117.082180  WGS84       Nitric oxide (NO)                    1  ...
# 6  -117.123964  NAD83       Nitric oxide (NO)                    1  ...
# 7  -117.396177  NAD83       Nitric oxide (NO)                    1  ...
# 8  -116.768293  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 9  -117.059088  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 10 -116.944308  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 11 -116.944308  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 12 -116.921350  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 13 -117.142665  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 14 -117.082180  WGS84  Nitrogen dioxide (NO2)                    1  ...
# 15 -117.123964  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 16 -117.396177  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 17 -116.944308  NAD83          Sulfur dioxide                    1  ...
# 18 -116.944308  NAD83         Carbon monoxide                    1  ...
# 19 -117.082180  WGS84         Carbon monoxide                    1  ...
# 20 -116.768293  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 21 -117.059088  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 22 -116.944308  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 23 -116.944308  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 24 -116.921350  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 25 -117.142665  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 26 -117.082180  WGS84  Nitrogen dioxide (NO2)                    1  ...
# 27 -117.123964  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 28 -117.396177  NAD83  Nitrogen dioxide (NO2)                    1  ...
# 29 -116.944308  NAD83          Sulfur dioxide                    1  ...
# 30 -116.944308  NAD83          Sulfur dioxide                    X  ...
# 31 -116.944308  NAD83          Sulfur dioxide                    Y  ...
# 32 -116.944308  NAD83          Sulfur dioxide                    H  ...
# 33 -116.944308  NAD83         Carbon monoxide                    Z  ...
# 34 -117.082180  WGS84         Carbon monoxide                    Z  ...
#
#    fiftieth_percentile tenth_percentile  \
# 0                0.000            0.000
# 1                1.000            0.000
# 2                0.500            0.000
# 3                1.000            0.000
# 4                1.000            0.000
# 5                6.000            1.000
# 6                0.000            0.000
# 7                0.000            0.000
# 8                3.000            1.000
# 9                5.000            1.000
# 10              12.000            3.000
# 11               6.000            2.000
# 12               5.000            2.000
# 13               6.000            2.000
# 14              12.000            5.000
# 15               5.000            1.000
# 16               4.000            1.000
# 17               0.100            0.000
# 18               0.256            0.162
# 19               0.500            0.200
# 20               9.000            4.000
# 21              16.000            6.000
# 22              26.000            8.000
# 23              12.000            5.000
# 24              16.000            5.000
# 25              18.000            5.000
# 26              21.000           11.000
# 27              15.000            5.000
# 28              13.000            4.000
# 29               0.200            0.000
# 30               0.100            0.000
# 31               0.100            0.000
# 32               0.100            0.000
# 33               0.300            0.200
# 34               0.500            0.300
#
#                            local_site_name                       site_address  \
# 0                                   Alpine          2300 VICTORIA DR., ALPINE
# 1                              Chula Vista         84 E. 'J' ST., CHULA VISTA
# 2   El Cajon - Lexington Elementary School                   533 First Street
# 3                                  Donovan         480 ALTA RD, OTAY MESA, CA
# 4    San Diego - Sherman Elementary School                   450B 24th Street
# 5           San Diego -Rancho Carmel Drive          11403 Rancho Carmel Drive
# 6                         Kearny Villa Rd.  6125A KEARNY VILLA RD., SAN DIEGO
# 7                           Camp Pendleton                   21441-W B STREET
# 8                                   Alpine          2300 VICTORIA DR., ALPINE
# 9                              Chula Vista         84 E. 'J' ST., CHULA VISTA
# 10  El Cajon - Lexington Elementary School                   533 First Street
# 11  El Cajon - Lexington Elementary School                   533 First Street
# 12                                 Donovan         480 ALTA RD, OTAY MESA, CA
# 13   San Diego - Sherman Elementary School                   450B 24th Street
# 14          San Diego -Rancho Carmel Drive          11403 Rancho Carmel Drive
# 15                        Kearny Villa Rd.  6125A KEARNY VILLA RD., SAN DIEGO
# 16                          Camp Pendleton                   21441-W B STREET
# 17  El Cajon - Lexington Elementary School                   533 First Street
# 18  El Cajon - Lexington Elementary School                   533 First Street
# 19          San Diego -Rancho Carmel Drive          11403 Rancho Carmel Drive
# 20                                  Alpine          2300 VICTORIA DR., ALPINE
# 21                             Chula Vista         84 E. 'J' ST., CHULA VISTA
# 22  El Cajon - Lexington Elementary School                   533 First Street
# 23  El Cajon - Lexington Elementary School                   533 First Street
# 24                                 Donovan         480 ALTA RD, OTAY MESA, CA
# 25   San Diego - Sherman Elementary School                   450B 24th Street
# 26          San Diego -Rancho Carmel Drive          11403 Rancho Carmel Drive
# 27                        Kearny Villa Rd.  6125A KEARNY VILLA RD., SAN DIEGO
# 28                          Camp Pendleton                   21441-W B STREET
# 29  El Cajon - Lexington Elementary School                   533 First Street
# 30  El Cajon - Lexington Elementary School                   533 First Street
# 31  El Cajon - Lexington Elementary School                   533 First Street
# 32  El Cajon - Lexington Elementary School                   533 First Street
# 33  El Cajon - Lexington Elementary School                   533 First Street
# 34          San Diego -Rancho Carmel Drive          11403 Rancho Carmel Drive
#
#          state     county                  city  cbsa_code  \
# 0   California  San Diego                Alpine      41740
# 1   California  San Diego           Chula Vista      41740
# 2   California  San Diego              El Cajon      41740
# 3   California  San Diego             Otay Mesa      41740
# 4   California  San Diego             San Diego      41740
# 5   California  San Diego             San Diego      41740
# 6   California  San Diego             San Diego      41740
# 7   California  San Diego  Camp Pendleton South      41740
# 8   California  San Diego                Alpine      41740
# 9   California  San Diego           Chula Vista      41740
# 10  California  San Diego              El Cajon      41740
# 11  California  San Diego              El Cajon      41740
# 12  California  San Diego             Otay Mesa      41740
# 13  California  San Diego             San Diego      41740
# 14  California  San Diego             San Diego      41740
# 15  California  San Diego             San Diego      41740
# 16  California  San Diego  Camp Pendleton South      41740
# 17  California  San Diego              El Cajon      41740
# 18  California  San Diego              El Cajon      41740
# 19  California  San Diego             San Diego      41740
# 20  California  San Diego                Alpine      41740
# 21  California  San Diego           Chula Vista      41740
# 22  California  San Diego              El Cajon      41740
# 23  California  San Diego              El Cajon      41740
# 24  California  San Diego             Otay Mesa      41740
# 25  California  San Diego             San Diego      41740
# 26  California  San Diego             San Diego      41740
# 27  California  San Diego             San Diego      41740
# 28  California  San Diego  Camp Pendleton South      41740
# 29  California  San Diego              El Cajon      41740
# 30  California  San Diego              El Cajon      41740
# 31  California  San Diego              El Cajon      41740
# 32  California  San Diego              El Cajon      41740
# 33  California  San Diego              El Cajon      41740
# 34  California  San Diego             San Diego      41740
#
#                       cbsa date_of_last_change
# 0   San Diego-Carlsbad, CA          2021-04-18
# 1   San Diego-Carlsbad, CA          2021-04-18
# 2   San Diego-Carlsbad, CA          2021-04-18
# 3   San Diego-Carlsbad, CA          2021-04-18
# 4   San Diego-Carlsbad, CA          2021-04-18
# 5   San Diego-Carlsbad, CA          2021-04-18
# 6   San Diego-Carlsbad, CA          2021-04-18
# 7   San Diego-Carlsbad, CA          2021-04-18
# 8   San Diego-Carlsbad, CA          2022-04-20
# 9   San Diego-Carlsbad, CA          2021-10-31
# 10  San Diego-Carlsbad, CA          2021-10-31
# 11  San Diego-Carlsbad, CA          2021-10-31
# 12  San Diego-Carlsbad, CA          2022-04-20
# 13  San Diego-Carlsbad, CA          2022-04-20
# 14  San Diego-Carlsbad, CA          2022-04-20
# 15  San Diego-Carlsbad, CA          2022-04-20
# 16  San Diego-Carlsbad, CA          2022-04-21
# 17  San Diego-Carlsbad, CA          2021-10-31
# 18  San Diego-Carlsbad, CA          2021-10-31
# 19  San Diego-Carlsbad, CA          2021-10-31
# 20  San Diego-Carlsbad, CA          2022-04-20
# 21  San Diego-Carlsbad, CA          2021-10-31
# 22  San Diego-Carlsbad, CA          2021-10-31
# 23  San Diego-Carlsbad, CA          2021-10-31
# 24  San Diego-Carlsbad, CA          2022-04-20
# 25  San Diego-Carlsbad, CA          2022-04-20
# 26  San Diego-Carlsbad, CA          2022-04-20
# 27  San Diego-Carlsbad, CA          2022-04-20
# 28  San Diego-Carlsbad, CA          2022-04-21
# 29  San Diego-Carlsbad, CA          2021-10-31
# 30  San Diego-Carlsbad, CA          2021-10-31
# 31  San Diego-Carlsbad, CA          2021-10-31
# 32  San Diego-Carlsbad, CA          2021-10-31
# 33  San Diego-Carlsbad, CA          2021-10-31
# 34  San Diego-Carlsbad, CA          2021-10-31
#
# [35 rows x 56 columns]

# %%
parameter_codes.to_csv('../data/parameter_codes.csv')

# %%
endpoint = 'https://aqs.epa.gov/data/api/annualData/byCounty?'
# email=test@aqs.api& key=test& param=88101,88502& bdate=20160101& edate=20160229& state=37& county=183"
# required parameters: email, key, param, bdate, edate, state, county

request_params = ','.join(param_list_limit)

params = {'email': epa_email,
          'key': epa_key,
          'param': request_params
          'bdate': '20190101',
          'edate': '20200101',
          'state': fips_ca,
          'county': fips_sd}

# WAIT AT LEAST 5 SECONDS BETWEEN LOOP ITERATIONS!!!

# %%
resp = requests.get(endpoint, params=params).json()

# %%
resp = pd.DataFrame(resp)

# %%
resp
